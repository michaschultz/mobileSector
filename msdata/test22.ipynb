# %%
from readflights import ReadFlights

import sys

rf = ReadFlights()
rf.open(fileName="/Users/micha/Downloads/t_future_flas_240_fra_03.csv.xz", nMax=sys.maxsize)

# 01 : 260m 23.2
# 03 : 216m 41.6
# Out:
# import flight SIA37K_
# import flight UAL1J_
# import flight SIA305K_
# import flight SIA335K_
# import flight SIA337F_
# import flight SIA25K_
# import flight SIA327K_
# import flight SIA51H_
# import flight SIA317K_
# import flight SIA377E_
# import flight SIA351I_
# import flight SIA391F_
# import flight SIA479K_
# import flight SIA282K_
# import flight SIA21K
# import flight SVA818D
# import flight QTR964J_
# import flight QTR942K
# import flight SIA7285B_
# import flight ETD470K
# import flight SIA21K_
# import flight QTR958K_
# import flight SVA818D_
# import flight CLX7947C
# import flight CLX7947C_
# import flight SIA27G
# import flight XAX523K_
# import flight RBA004K
# import flight ANA885K_
# import flight SIA495K_
# import flight SIA35E
# import flight UAE9820C_
# import flight AIC342K
# import flight CTM1018A
# import flight UAE433U_
# import flight BAW11K
# import flight CTM1018A_
# import flight SIA423J
# import flight SIA403K_
# import flight KLM835U
# ...
